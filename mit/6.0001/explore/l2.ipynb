# %% [markdown]
# ## Strings
# * letters, special characters, spaces, digits
# * enclose in quotation marks or single quotes
#
#     hi = "hello there"
#  * concatenate strings
#
#    name = "ana"
#
#    greet = hi +name
#
#    greeting = hi + " " + name
#
# *  do some operations on a string as defined in python docs
#
#     silly = hi + " " + name * 3

# %%
hi = "hello there"
name = "mamta"
greet = hi + name
print(greet)
# Out:
# hello theremamta

# %%
hi = "hello there"
name = "mamta"
greet = hi + " "  + name
print(greet)
# Out:
# hello there mamta

# %%
hi = "hello there"
name = "mamta"
greet = hi +  " "  + name
print(greet)
silly = hi + (" " + name)*3
print(silly)
# Out:
# hello there mamta
# hello there mamta mamta mamta

# %%
hi = "hello there"
name = "mamta"
greet = hi +  " "  + name
print(greet)
silly = (hi + (" " + name))*3
print(silly)
# Out:
# hello there mamta
# hello there mamtahello there mamtahello there mamta

# %%
x = 1
print(x)
x_str = str(x)
print("my fav number is", x, ".", "x =", x)
print("my fav number is " + x_str + "." + "x = " + x_str)  
print("my fav number is " + x_str + "." + "x = " + str(x))
# Out:
# 1
# my fav number is 1 . x = 1
# my fav number is 1.x = 1
# my fav number is 1.x = 1

# %% [markdown]
# ## input/output : print
# * used to output stuff to console
# * keyword is print
#
#   x = 1
#
#   print(x)
#
#   x_str = str(x)
#
#   print ("my fav num is", x, ".", "x =", x)
#
#   print ("my fav num is" +x_str + "."+"x = "+_str)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
text = input ("type anything... ")
print(5*text)
num = int(input("type a number... "))
print(5*num)
# Out:
# 55555
# 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# example

# %%
x = float(input("enter a number for x: "))
y = float(input("enter a number for y: "))
if x == y:
    print("x and y are equal")
    if y != 0:
        print("therefore, x / y is", x/y)
elif x < y:
     print("x is smaller")
else:   
    print("y is smaller")
print("thanks!")
# Out:
# x is smaller
# thanks!

# %%
x = float(input("enter a number for x: "))
y = float(input("enter a number for y: "))
if x == y:
print("x and y are equal")
if y != 0:
print("therefore, x / y is", x/y)
elif x < y:
print("x is smaller")
else:   
print("y is smaller")
print("thanks!")
# Out:
#   Cell In[5], line 4
#     print("x and y are equal")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
if <exit right>:
    <set background to woods_background>
if <exit right>:
    <set background to woods_background>
    if <exit right>:
        <set backgroung to woods_background>
        and so on and on and on...
    else:
        <set background to woods_background>
else:
    <set background to exit_background>
    if <exit right>:
        <set background to exit_background>
    else:
        <set background to exit_background>
# Out:
#   Cell In[14], line 1
#     if <exit right>:
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = input("you are in the lost forest\n********")
while n == "left" or n == "right":
    n = input("you are in the lost forest\n********")
print("\nyou got out of the lost forest!\n\o/")
# Out:
# you got out of the lost forest!
# \o/

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 0
while n < 5:
    print(n)
    n = n+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for n in range(5):
    print(n)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mysum = 0
for i in range(7,10):
    mysum += i
    print(mysum)
# Out:
# 7
# 15
# 24

# %%
mysum = 0
for i in range(5, 11,2):
    mysum += i
print(mysum)
# Out:
# 21

# %%
mysum = 0
for i in range(6, 15,3):
    mysum += i
print(mysum)

# %%
mysum = 0
for i in range(5, 11,2):
    mysum += i
    if mysum == 5:
        break
    mysum +=1
print(mysum)
# Out:
# 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
